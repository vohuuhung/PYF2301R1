# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bai 1
diem_toan = 8.5
diem_ly = 7.5
diem_hoa = 8
diem_trung_binh = (diem_toan + diem_ly + diem_hoa)/3
print(diem_trung_binh >= 8)
print(diem_trung_binh >= 6 and diem_trung_binh < 8)
print(diem_trung_binh < 6)final_exam_mark = 7.5
# Out:
# True
# False
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# bai 2
participation_percent = 0.75

course_complete_percent = 0.80

final_exam_mark = 7.5

pass_point =(participation_percent > 0.75 and course_complete_percent > 0.80 and final_exam_mark >= 7.5)

print(pass_point)
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# bai 3
distance = 33
# cau a
distanceA = (distance / 60 ) * 1000
print("Trung binh moi phut doan tau do di duoc " + str(distanceA) + " m" )
# cau b
distanceB = (distance / 60) * 72 
print("Sau 1 gio 12 phut doan tau do di duoc " + str(distanceB) + " km")
# Out:
# Trung binh moi phut doan tau do di duoc 550.0 m
# Sau 1 gio 12 phut doan tau do di duoc 39.6 km

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Bai 4
chieu_dai = 16
chieu_rong = 10
dien_tich1 = chieu_dai* chieu_rong

chieu_dai += 4
dien_tich2 = chieu_dai*chieu_rong
phan_tram = ( dien_tich2 - dien_tich1) / dien_tich1 *100
print("neu chieu dai tang them 4m thi dien tich cua hinh chu nhan se tang them " + str(phan_tram) + " phan tram ")
# Out:
# neu chieu dai tang them 4m thi dien tich cua hinh chu nhan se tang them 25.0 phan tram
